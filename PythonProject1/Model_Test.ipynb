# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import shutil
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
model = YOLO(r"C:\Pfe_Mokh++\Detection_Conteneur\PythonProject1\PythonProject1\runs\detect\train2\weights\best.pt")

shutil.copy(
    r"C:\Pfe_Mokh++\Detection_Conteneur\PythonProject1\PythonProject1\runs\detect\train2\weights\best.pt",
    r"C:\Pfe_Mokh++\Detection_Conteneur\PythonProject1\PythonProject1\model\mon_model.pt"
)
print("Modèle enregistré avec succès !")
# Out:
# Modèle enregistré avec succès !

# %%
image_path = r"C:\Pfe_Mokh++\Detection_Conteneur\PythonProject1\Detection_Numeros_Conteneurs.v1-2025-03-28-9-56pm.yolov8\test\images\700135891807221341_0050_jpg.rf.0d331182340c4db39c468e6b03035b6c.jpg"

results = model(image_path)
result_img = results[0].plot()

plt.figure(figsize=(10, 10))
plt.imshow(result_img)
plt.axis("off")
plt.title("Image avec détections")
plt.show()
# Out:
# image 1/1 C:\Pfe_Mokh++\Detection_Conteneur\PythonProject1\Detection_Numeros_Conteneurs.v1-2025-03-28-9-56pm.yolov8\test\images\700135891807221341_0050_jpg.rf.0d331182340c4db39c468e6b03035b6c.jpg: 640x640 1 container - v3 2025-01-09 2-02pm, 100.5ms
# Speed: 3.9ms preprocess, 100.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
